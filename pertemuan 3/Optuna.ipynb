# %% [markdown]
# # Overview Materi

# %% [markdown]
# Jelaskan perbedaan singkat antara grid, randomized, bayesian search cv dengan optuna menurut pemahamanmu
#
# Grid: Mencoba semua kombinasi hyperparameter dari grid yang sudah ditentukan
#
# Randomized: Memilih kombinasi acak dari distribusi hyperparameter yang ditentukan
#
# Bayesian search cv: Memakai model probabilistik untuk memprediksi daerah mana yang paling menjanjikan, lalu mengeksplorasi ke sana
#
# source: https://www.youtube.com/watch?v=t-INgABWULw

# %% [markdown]
# # Import Data & Libraries

# %%
# jalankan hanya sekali
# !pip install optuna -q

# %%
# import library yang dibutuhkan di sini
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = sns.load_dataset('iris')

print(df.head())
print(df.tail())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
new_df = df.copy()

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %% [markdown]
# # Data Preprocessing

# %%
# ubah variabel kategorik ke numerik
spe_map = {"setosa": 0, "versicolor": 1, "virginica": 2}
df["species"] = df["species"].str.lower().map(spe_map)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# subsetting peubah
X = df.drop(['species'], axis=1)
y = df['species']

# %% [markdown]
# # Dataset Splitting

# %%
# split dengan rasio 80:20
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, train_size=0.8, random_state=42)

train, test = train_test_split(df, test_size = 0.2, train_size=0.8, random_state=42)

# %%
train.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  species
# 22           4.6          3.6           1.0          0.2        0
# 15           5.7          4.4           1.5          0.4        0
# 65           6.7          3.1           4.4          1.4        1
# 11           4.8          3.4           1.6          0.2        0
# 42           4.4          3.2           1.3          0.2        0

# %%
test.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 73            6.1          2.8           4.7          1.2        1
# 18            5.7          3.8           1.7          0.3        0
# 118           7.7          2.6           6.9          2.3        2
# 78            6.0          2.9           4.5          1.5        1
# 76            6.8          2.8           4.8          1.4        1

# %% [markdown]
# # Base Model Random Forest

# %%
# gunakan random forest classifier
from sklearn.ensemble import RandomForestClassifier


rfr = RandomForestClassifier(random_state=42)
rfr.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rfr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

print(f"Accuracy: {accuracy_score(y_test, y_pred):.3f}")
print(f"Precision: {precision_score(y_test, y_pred, average='weighted'):.3f}")
print(f"Recall: {recall_score(y_test, y_pred, average='weighted'):.3f}")
print(f"F1 Score: {f1_score(y_test, y_pred, average='weighted'):.3f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.000
# Precision: 1.000
# Recall: 1.000
# F1 Score: 1.000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# # Optuna

# %%
import optuna

# %%
from sklearn.model_selection import cross_val_score

# %%
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 100, 1000)
    max_depth = trial.suggest_int('max_depth', 10, 100)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 32)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 32)

    model = RandomForestClassifier(n_estimators = n_estimators,
                                   max_depth = max_depth,
                                   min_samples_split = min_samples_split,
                                   min_samples_leaf = min_samples_leaf,
                                   random_state=42)

    score = cross_val_score(model, X_train, y_train, cv=5, scoring="accuracy")
    return score.mean()

# %% [markdown]
# Hyperparameter dapat disesuaikan dengan algoritma yang digunakan. Kali ini kita menggunakan Random Forest sehingga yang dapat kita select adalah *n_estimators, max_depth, min_samples_split,* dan *min_samples_leaf*

# %%
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.RandomSampler())
# Out:
# [I 2025-10-03 16:11:36,459] A new study created in memory with name: no-name-4b331d36-6798-485c-b567-e7b7ed681d6a

# %%
study.optimize(objective, n_trials=100)
# Out:
# [I 2025-10-03 16:12:35,009] Trial 0 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 751, 'max_depth': 32, 'min_samples_split': 25, 'min_samples_leaf': 16}. Best is trial 0 with value: 0.9416666666666667.
# [I 2025-10-03 16:12:39,963] Trial 1 finished with value: 0.7 and parameters: {'n_estimators': 563, 'max_depth': 78, 'min_samples_split': 5, 'min_samples_leaf': 30}. Best is trial 0 with value: 0.9416666666666667.
# [I 2025-10-03 16:12:42,405] Trial 2 finished with value: 0.8166666666666668 and parameters: {'n_estimators': 189, 'max_depth': 80, 'min_samples_split': 4, 'min_samples_leaf': 24}. Best is trial 0 with value: 0.9416666666666667.
# [I 2025-10-03 16:12:47,976] Trial 3 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 709, 'max_depth': 74, 'min_samples_split': 16, 'min_samples_leaf': 12}. Best is trial 0 with value: 0.9416666666666667.
# [I 2025-10-03 16:12:49,461] Trial 4 finished with value: 0.7 and parameters: {'n_estimators': 188, 'max_depth': 85, 'min_samples_split': 9, 'min_samples_leaf': 29}. Best is trial 0 with value: 0.9416666666666667.
# [I 2025-10-03 16:12:55,320] Trial 5 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 614, 'max_depth': 26, 'min_samples_split': 16, 'min_samples_leaf': 17}. Best is trial 0 with value: 0.9416666666666667.
# [I 2025-10-03 16:12:56,876] Trial 6 finished with value: 0.95 and parameters: {'n_estimators': 184, 'max_depth': 22, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:13:01,425] Trial 7 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 576, 'max_depth': 23, 'min_samples_split': 24, 'min_samples_leaf': 17}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:13:05,962] Trial 8 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 538, 'max_depth': 31, 'min_samples_split': 15, 'min_samples_leaf': 4}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:13:08,214] Trial 9 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 185, 'max_depth': 51, 'min_samples_split': 15, 'min_samples_leaf': 15}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:13:11,766] Trial 10 finished with value: 0.7 and parameters: {'n_estimators': 453, 'max_depth': 74, 'min_samples_split': 22, 'min_samples_leaf': 32}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:13:16,251] Trial 11 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 555, 'max_depth': 93, 'min_samples_split': 14, 'min_samples_leaf': 10}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:13:24,702] Trial 12 finished with value: 0.8 and parameters: {'n_estimators': 872, 'max_depth': 96, 'min_samples_split': 26, 'min_samples_leaf': 25}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:13:31,768] Trial 13 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 848, 'max_depth': 41, 'min_samples_split': 29, 'min_samples_leaf': 18}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:13:40,031] Trial 14 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 960, 'max_depth': 46, 'min_samples_split': 15, 'min_samples_leaf': 3}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:13:44,369] Trial 15 finished with value: 0.95 and parameters: {'n_estimators': 510, 'max_depth': 83, 'min_samples_split': 8, 'min_samples_leaf': 20}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:13:49,933] Trial 16 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 597, 'max_depth': 72, 'min_samples_split': 8, 'min_samples_leaf': 6}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:13:56,417] Trial 17 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 765, 'max_depth': 46, 'min_samples_split': 25, 'min_samples_leaf': 10}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:14:03,061] Trial 18 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 693, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:14:04,323] Trial 19 finished with value: 0.9416666666666668 and parameters: {'n_estimators': 156, 'max_depth': 84, 'min_samples_split': 20, 'min_samples_leaf': 20}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:14:09,163] Trial 20 finished with value: 0.7 and parameters: {'n_estimators': 611, 'max_depth': 65, 'min_samples_split': 9, 'min_samples_leaf': 32}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:14:14,849] Trial 21 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 517, 'max_depth': 73, 'min_samples_split': 3, 'min_samples_leaf': 14}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:14:20,854] Trial 22 finished with value: 0.7 and parameters: {'n_estimators': 696, 'max_depth': 100, 'min_samples_split': 6, 'min_samples_leaf': 30}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:14:23,576] Trial 23 finished with value: 0.9166666666666666 and parameters: {'n_estimators': 267, 'max_depth': 86, 'min_samples_split': 3, 'min_samples_leaf': 21}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:14:28,282] Trial 24 finished with value: 0.7416666666666666 and parameters: {'n_estimators': 520, 'max_depth': 77, 'min_samples_split': 10, 'min_samples_leaf': 27}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:14:30,287] Trial 25 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 251, 'max_depth': 96, 'min_samples_split': 23, 'min_samples_leaf': 6}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:14:36,825] Trial 26 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 658, 'max_depth': 30, 'min_samples_split': 16, 'min_samples_leaf': 8}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:14:45,419] Trial 27 finished with value: 0.9166666666666666 and parameters: {'n_estimators': 970, 'max_depth': 76, 'min_samples_split': 14, 'min_samples_leaf': 21}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:14:47,935] Trial 28 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 316, 'max_depth': 15, 'min_samples_split': 28, 'min_samples_leaf': 13}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:14:48,803] Trial 29 finished with value: 0.7083333333333333 and parameters: {'n_estimators': 107, 'max_depth': 96, 'min_samples_split': 25, 'min_samples_leaf': 31}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:14:55,176] Trial 30 finished with value: 0.7083333333333333 and parameters: {'n_estimators': 679, 'max_depth': 88, 'min_samples_split': 24, 'min_samples_leaf': 31}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:15:00,120] Trial 31 finished with value: 0.7083333333333333 and parameters: {'n_estimators': 623, 'max_depth': 22, 'min_samples_split': 13, 'min_samples_leaf': 28}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:15:06,471] Trial 32 finished with value: 0.7083333333333333 and parameters: {'n_estimators': 644, 'max_depth': 14, 'min_samples_split': 25, 'min_samples_leaf': 31}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:15:08,562] Trial 33 finished with value: 0.925 and parameters: {'n_estimators': 261, 'max_depth': 89, 'min_samples_split': 13, 'min_samples_leaf': 19}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:15:09,666] Trial 34 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 135, 'max_depth': 73, 'min_samples_split': 17, 'min_samples_leaf': 17}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:15:17,016] Trial 35 finished with value: 0.7666666666666666 and parameters: {'n_estimators': 828, 'max_depth': 73, 'min_samples_split': 26, 'min_samples_leaf': 26}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:15:19,794] Trial 36 finished with value: 0.95 and parameters: {'n_estimators': 336, 'max_depth': 51, 'min_samples_split': 23, 'min_samples_leaf': 20}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:15:23,419] Trial 37 finished with value: 0.7 and parameters: {'n_estimators': 455, 'max_depth': 88, 'min_samples_split': 12, 'min_samples_leaf': 29}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:15:25,031] Trial 38 finished with value: 0.7 and parameters: {'n_estimators': 203, 'max_depth': 35, 'min_samples_split': 19, 'min_samples_leaf': 29}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:15:26,565] Trial 39 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 194, 'max_depth': 65, 'min_samples_split': 2, 'min_samples_leaf': 16}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:15:30,968] Trial 40 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 421, 'max_depth': 62, 'min_samples_split': 5, 'min_samples_leaf': 16}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:15:32,227] Trial 41 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 154, 'max_depth': 22, 'min_samples_split': 12, 'min_samples_leaf': 16}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:15:38,037] Trial 42 finished with value: 0.9083333333333332 and parameters: {'n_estimators': 731, 'max_depth': 77, 'min_samples_split': 19, 'min_samples_leaf': 22}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:15:42,409] Trial 43 finished with value: 0.7083333333333333 and parameters: {'n_estimators': 440, 'max_depth': 26, 'min_samples_split': 5, 'min_samples_leaf': 28}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:15:44,763] Trial 44 finished with value: 0.7083333333333333 and parameters: {'n_estimators': 282, 'max_depth': 77, 'min_samples_split': 28, 'min_samples_leaf': 29}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:15:47,201] Trial 45 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 307, 'max_depth': 76, 'min_samples_split': 23, 'min_samples_leaf': 5}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:15:48,381] Trial 46 finished with value: 0.9083333333333332 and parameters: {'n_estimators': 147, 'max_depth': 26, 'min_samples_split': 29, 'min_samples_leaf': 22}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:15:51,039] Trial 47 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 334, 'max_depth': 61, 'min_samples_split': 8, 'min_samples_leaf': 8}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:15:52,289] Trial 48 finished with value: 0.6916666666666667 and parameters: {'n_estimators': 157, 'max_depth': 68, 'min_samples_split': 19, 'min_samples_leaf': 29}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:15:57,673] Trial 49 finished with value: 0.7416666666666666 and parameters: {'n_estimators': 550, 'max_depth': 69, 'min_samples_split': 14, 'min_samples_leaf': 27}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:16:02,370] Trial 50 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 591, 'max_depth': 100, 'min_samples_split': 18, 'min_samples_leaf': 9}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:16:10,731] Trial 51 finished with value: 0.95 and parameters: {'n_estimators': 912, 'max_depth': 66, 'min_samples_split': 11, 'min_samples_leaf': 1}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:16:17,548] Trial 52 finished with value: 0.7083333333333333 and parameters: {'n_estimators': 880, 'max_depth': 16, 'min_samples_split': 32, 'min_samples_leaf': 28}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:16:23,385] Trial 53 finished with value: 0.7 and parameters: {'n_estimators': 611, 'max_depth': 72, 'min_samples_split': 23, 'min_samples_leaf': 29}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:16:31,113] Trial 54 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 980, 'max_depth': 77, 'min_samples_split': 24, 'min_samples_leaf': 12}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:16:37,235] Trial 55 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 637, 'max_depth': 84, 'min_samples_split': 25, 'min_samples_leaf': 3}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:16:40,940] Trial 56 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 458, 'max_depth': 95, 'min_samples_split': 27, 'min_samples_leaf': 2}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:16:42,305] Trial 57 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 162, 'max_depth': 54, 'min_samples_split': 30, 'min_samples_leaf': 10}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:16:45,811] Trial 58 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 347, 'max_depth': 68, 'min_samples_split': 11, 'min_samples_leaf': 16}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:16:52,621] Trial 59 finished with value: 0.7 and parameters: {'n_estimators': 837, 'max_depth': 32, 'min_samples_split': 9, 'min_samples_leaf': 30}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:16:55,626] Trial 60 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 376, 'max_depth': 93, 'min_samples_split': 21, 'min_samples_leaf': 6}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:16:58,580] Trial 61 finished with value: 0.7083333333333333 and parameters: {'n_estimators': 274, 'max_depth': 72, 'min_samples_split': 13, 'min_samples_leaf': 29}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:17:06,195] Trial 62 finished with value: 0.7 and parameters: {'n_estimators': 931, 'max_depth': 74, 'min_samples_split': 31, 'min_samples_leaf': 30}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:17:07,471] Trial 63 finished with value: 0.8666666666666666 and parameters: {'n_estimators': 159, 'max_depth': 43, 'min_samples_split': 9, 'min_samples_leaf': 23}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:17:13,501] Trial 64 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 618, 'max_depth': 65, 'min_samples_split': 12, 'min_samples_leaf': 8}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:17:18,205] Trial 65 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 589, 'max_depth': 38, 'min_samples_split': 28, 'min_samples_leaf': 2}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:17:19,185] Trial 66 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 120, 'max_depth': 64, 'min_samples_split': 15, 'min_samples_leaf': 4}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:17:25,131] Trial 67 finished with value: 0.9166666666666666 and parameters: {'n_estimators': 617, 'max_depth': 98, 'min_samples_split': 12, 'min_samples_leaf': 21}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:17:27,192] Trial 68 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 257, 'max_depth': 91, 'min_samples_split': 21, 'min_samples_leaf': 10}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:17:32,159] Trial 69 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 622, 'max_depth': 24, 'min_samples_split': 2, 'min_samples_leaf': 3}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:17:33,032] Trial 70 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 107, 'max_depth': 96, 'min_samples_split': 26, 'min_samples_leaf': 13}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:17:40,622] Trial 71 finished with value: 0.9083333333333332 and parameters: {'n_estimators': 834, 'max_depth': 35, 'min_samples_split': 17, 'min_samples_leaf': 22}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:17:47,486] Trial 72 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 861, 'max_depth': 30, 'min_samples_split': 30, 'min_samples_leaf': 7}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:17:54,625] Trial 73 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 772, 'max_depth': 68, 'min_samples_split': 14, 'min_samples_leaf': 13}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:17:57,670] Trial 74 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 370, 'max_depth': 40, 'min_samples_split': 4, 'min_samples_leaf': 10}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:18:00,907] Trial 75 finished with value: 0.9166666666666666 and parameters: {'n_estimators': 374, 'max_depth': 84, 'min_samples_split': 24, 'min_samples_leaf': 21}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:18:06,728] Trial 76 finished with value: 0.8 and parameters: {'n_estimators': 627, 'max_depth': 33, 'min_samples_split': 17, 'min_samples_leaf': 25}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:18:10,371] Trial 77 finished with value: 0.825 and parameters: {'n_estimators': 457, 'max_depth': 37, 'min_samples_split': 20, 'min_samples_leaf': 24}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:18:11,972] Trial 78 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 202, 'max_depth': 35, 'min_samples_split': 31, 'min_samples_leaf': 19}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:18:19,188] Trial 79 finished with value: 0.825 and parameters: {'n_estimators': 774, 'max_depth': 16, 'min_samples_split': 22, 'min_samples_leaf': 24}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:18:24,044] Trial 80 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 591, 'max_depth': 37, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:18:30,065] Trial 81 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 625, 'max_depth': 99, 'min_samples_split': 20, 'min_samples_leaf': 17}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:18:31,526] Trial 82 finished with value: 0.8666666666666666 and parameters: {'n_estimators': 184, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 23}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:18:35,095] Trial 83 finished with value: 0.9166666666666666 and parameters: {'n_estimators': 452, 'max_depth': 68, 'min_samples_split': 10, 'min_samples_leaf': 21}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:18:42,731] Trial 84 finished with value: 0.825 and parameters: {'n_estimators': 838, 'max_depth': 77, 'min_samples_split': 15, 'min_samples_leaf': 24}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:18:49,714] Trial 85 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 886, 'max_depth': 74, 'min_samples_split': 19, 'min_samples_leaf': 18}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:18:58,209] Trial 86 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 949, 'max_depth': 28, 'min_samples_split': 10, 'min_samples_leaf': 18}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:19:05,322] Trial 87 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 848, 'max_depth': 40, 'min_samples_split': 31, 'min_samples_leaf': 18}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:19:08,983] Trial 88 finished with value: 0.7833333333333333 and parameters: {'n_estimators': 389, 'max_depth': 68, 'min_samples_split': 14, 'min_samples_leaf': 25}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:19:14,193] Trial 89 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 638, 'max_depth': 10, 'min_samples_split': 17, 'min_samples_leaf': 9}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:19:22,696] Trial 90 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 791, 'max_depth': 51, 'min_samples_split': 21, 'min_samples_leaf': 12}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:19:23,730] Trial 91 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 127, 'max_depth': 96, 'min_samples_split': 31, 'min_samples_leaf': 9}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:19:27,696] Trial 92 finished with value: 0.7 and parameters: {'n_estimators': 499, 'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 30}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:19:31,422] Trial 93 finished with value: 0.7916666666666667 and parameters: {'n_estimators': 397, 'max_depth': 53, 'min_samples_split': 21, 'min_samples_leaf': 25}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:19:38,223] Trial 94 finished with value: 0.8 and parameters: {'n_estimators': 793, 'max_depth': 38, 'min_samples_split': 10, 'min_samples_leaf': 25}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:19:42,619] Trial 95 finished with value: 0.8 and parameters: {'n_estimators': 548, 'max_depth': 65, 'min_samples_split': 25, 'min_samples_leaf': 25}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:19:47,781] Trial 96 finished with value: 0.925 and parameters: {'n_estimators': 503, 'max_depth': 62, 'min_samples_split': 5, 'min_samples_leaf': 18}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:19:50,077] Trial 97 finished with value: 0.825 and parameters: {'n_estimators': 283, 'max_depth': 48, 'min_samples_split': 17, 'min_samples_leaf': 24}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:19:54,583] Trial 98 finished with value: 0.7083333333333333 and parameters: {'n_estimators': 557, 'max_depth': 13, 'min_samples_split': 17, 'min_samples_leaf': 28}. Best is trial 6 with value: 0.95.
# [I 2025-10-03 16:19:58,462] Trial 99 finished with value: 0.8333333333333333 and parameters: {'n_estimators': 349, 'max_depth': 43, 'min_samples_split': 23, 'min_samples_leaf': 24}. Best is trial 6 with value: 0.95.

# %% [markdown]
# it may take a while... so just wait n see ^^
# <br>
# they recommend to set n_trials at 100 cz it seems there's no significant score increase after 100 trials (also inefficient too, you'll have to wait in a quite long time)

# %%
study.best_params
# Out:
# {'n_estimators': 184,
#  'max_depth': 22,
#  'min_samples_split': 10,
#  'min_samples_leaf': 1}

# %% [markdown]
# Berikut hasil hyperparameter tuning dari Optuna

# %%
# cek hasil hyperparameter tuning dari Optuna
best_params = study.best_params

# %% [markdown]
# # Random Forest Using Optuna

# %%
# simpan hasil best hyperparameter tuning ke variabel bari
best_n_estimators = best_params['n_estimators']
best_max_depth = best_params['max_depth']
best_min_samples_split = best_params['min_samples_split']
best_min_samples_leaf = best_params['min_samples_leaf']

# %%
best_model = RandomForestClassifier(n_estimators=best_n_estimators,
                                    max_depth=best_max_depth,
                                    min_samples_split=best_min_samples_split,
                                    min_samples_leaf=best_min_samples_leaf)

best_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=22, min_samples_split=10, n_estimators=184)

# %%
y_pred = best_model.predict(X_test)

# %%
print(f"Accuracy: {accuracy_score(y_test, y_pred):.3f}")
print(f"Precision: {precision_score(y_test, y_pred, average='weighted'):.3f}")
print(f"Recall: {recall_score(y_test, y_pred, average='weighted'):.3f}")
print(f"F1 Score: {f1_score(y_test, y_pred, average='weighted'):.3f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.000
# Precision: 1.000
# Recall: 1.000
# F1 Score: 1.000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# Tidak terdapat kenaikan skor dengan sebelum menggunakan Optuna sebab skor yang dihasilkan melalui base model saja sudah bagus
